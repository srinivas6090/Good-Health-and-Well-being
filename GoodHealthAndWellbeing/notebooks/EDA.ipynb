# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/health_data.csv')

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               51 non-null     int64
#  1   Gender            51 non-null     object
#  2   BMI               51 non-null     float64
#  3   BloodPressure     51 non-null     int64
#  4   Cholesterol       51 non-null     int64
#  5   BloodSugar        51 non-null     object
#  6   SmokingStatus     51 non-null     object
#  7   PhysicalActivity  51 non-null     int64
#  8   ChronicDiseases   51 non-null     int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 3.7+ KB
# None
#              Age        BMI  BloodPressure  Cholesterol  PhysicalActivity  \
# count  51.000000  51.000000      51.000000    51.000000         51.000000
# mean   51.117647  25.333333     118.431373   180.196078          1.960784
# std    16.545268   2.599359      22.416293    53.795546          1.182553
# min    22.000000  20.000000      90.000000   110.000000          0.000000
# 25%    38.500000  23.500000     100.000000   140.000000          1.000000
# 50%    49.000000  25.000000     110.000000   160.000000          2.000000
# 75%    65.500000  27.000000     130.000000   200.000000          3.000000
# max    82.000000  30.000000     165.000000   290.000000          4.000000
#
#        ChronicDiseases
# count        51.000000
# mean          1.176471
# std           1.090062
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max           3.000000

# %%
print(df.isnull().sum())
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# Cholesterol         0
# BloodSugar          0
# SmokingStatus       0
# PhysicalActivity    0
# ChronicDiseases     0
# dtype: int64

# %%
for column in ['Age', 'BMI', 'BloodPressure', 'Cholesterol']:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# Filter for numerical columns only
numeric_df = df.select_dtypes(include=['number'])

# Plot the correlation matrix heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
